# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd    
from seaborn import lmplot
pd.options.mode.copy_on_write = True

# %%
MA = pd.read_excel(r"C:\Users\c-lop\Documents\GitHub\Mama_analisis\mama_muestra1_Analisis.xlsx")

# %%
MA.describe()
# Out:
#            id_int  blank1  blank1.1  blank1.2  isocentros  camposverif  \
# count  192.000000     0.0       0.0       0.0  192.000000   192.000000
# mean    96.500000     NaN       NaN       NaN    1.067708     2.963542
# std     55.569776     NaN       NaN       NaN    0.422655     1.118022
# min      1.000000     NaN       NaN       NaN    1.000000     2.000000
# 25%     48.750000     NaN       NaN       NaN    1.000000     2.000000
# 50%     96.500000     NaN       NaN       NaN    1.000000     2.000000
# 75%    144.250000     NaN       NaN       NaN    1.000000     4.000000
# max    192.000000     NaN       NaN       NaN    4.000000    10.000000
#
#           dosisFx          Fx   dosisTotal  contrastAgent  ...  ncampoverif  \
# count  192.000000  192.000000   192.000000            0.0  ...   192.000000
# mean   362.213542   10.713542  3285.171875            NaN  ...     1.697917
# std    137.756828    5.252397   967.478499            NaN  ...     0.688268
# min    200.000000    1.000000   800.000000            NaN  ...     0.000000
# 25%    267.000000    5.000000  2600.000000            NaN  ...     1.000000
# 50%    267.000000   15.000000  4005.000000            NaN  ...     2.000000
# 75%    520.000000   15.000000  4005.000000            NaN  ...     2.000000
# max    800.000000   25.000000  5000.000000            NaN  ...     3.000000
#
#          DoseMax3D      UMtotal  DosisXplan  free2   PesoTotal  \
# count   192.000000   192.000000  192.000000    0.0  191.000000
# mean   3634.640332   585.382812    0.994792    NaN    2.583872
# std    1110.355428   152.066836    0.072169    NaN    0.858242
# min     888.894891   220.400000    0.000000    NaN    1.000000
# 25%    2806.824717   593.375000    1.000000    NaN    2.000000
# 50%    4361.929887   631.400000    1.000000    NaN    2.000000
# 75%    4518.216717   660.450000    1.000000    NaN    3.294273
# max    5602.955056  1261.900000    1.000000    NaN    4.025000
#
#        ComentarioStruct  level           d    h
# count               0.0  184.0  189.000000  0.0
# mean                NaN    0.0   15.619048  NaN
# std                 NaN    0.0    8.783014  NaN
# min                 NaN    0.0    1.000000  NaN
# 25%                 NaN    0.0    9.000000  NaN
# 50%                 NaN    0.0   15.000000  NaN
# 75%                 NaN    0.0   24.000000  NaN
# max                 NaN    0.0   31.000000  NaN
#
# [8 rows x 23 columns]

# %%
#Equipo
sns.set(rc={'figure.figsize':(8,6)})
ax = sns.histplot(MA["equipo"], color = "darkcyan", edgecolor = "black", alpha = 0.75)

for i in ax.containers:
    ax.bar_label(i,)
    
plt.title("Equipo asignado al tratamiento",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Equipo",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("equipo_hist.pdf",bbox_inches="tight")

# %%
#Accesorios

ACC = MA["accesorio"]

for i in range(len(MA["accesorio"])-1):
    if ACC[i] == "MLC-DoseDynamic/MLC-Static":
        ACC[i] = "MLC-Static/MLC-DoseDynamic"
        
for i in range(len(MA["accesorio"])-1):
    if ACC[i] == "MLC-DoseDynamic/Bolus/MLC-Static":
        ACC[i] = "MLC-Static/Bolus/MLC-DoseDynamic"

sns.set(rc={'figure.figsize':(8,6)})
ax = sns.histplot(ACC, color = "darkcyan", edgecolor = "black", alpha = 0.75)

for i in ax.containers:
    ax.bar_label(i,)

plt.title("Accesorios del LINAC",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Accesorio(s)",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.xticks(rotation='vertical')
plt.show()
#plt.savefig("accesorios_hist.pdf",bbox_inches="tight")

# %%
#Energías

EE = MA["energia"]

for i in range(len(MA["accesorio"])-1):
    if EE[i] == "15X/6X":
        EE[i] = "6X/15X"

sns.set(rc={'figure.figsize':(8,6)})
ax = sns.histplot(EE, color = "darkcyan", edgecolor = "black", alpha = 0.75)

for i in ax.containers:
    ax.bar_label(i,)
    
plt.title("Energías del LINAC",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Energía",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("energias_hist.pdf",bbox_inches="tight")

# %%
#Isocentros
sns.set(rc={'figure.figsize':(8,6)})
ax = sns.histplot(MA["isocentros"], color = "darkcyan", edgecolor = "black", alpha = 0.75, discrete=True)

for i in ax.containers:
    ax.bar_label(i,)
    
plt.title("Isocentros del tratamiento",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Número de isocentros",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")

# %%
#Isocentros
sns.set(rc={'figure.figsize':(8,6)})
sns.histplot(MA["isocentros"], color = "darkcyan", edgecolor = "black", alpha = 0.75, kde=True, line_kws={"color": "b", "lw" : 3})
plt.title("Isocentros del tratamiento",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Número de isocentros",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")

# %%
#DosisFx
sns.set(rc={'figure.figsize':(8,6)})
ax = sns.histplot(MA["dosisFx"], color = "darkcyan", edgecolor = "black", alpha = 0.75)

for i in ax.containers:
    ax.bar_label(i,)
    
plt.title("Dosis por fracción",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Dosis [cGy]",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")

# %%
#2
sns.set(rc={'figure.figsize':(8,6)})
sns.histplot(MA["dosisFx"], color = "darkcyan", edgecolor = "black", alpha = 0.75, kde=True, line_kws={"color": "b", "lw" : 3})
plt.title("Dosis por fracción",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Dosis [cGy]",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")

# %%
#3
sns.set(rc={'figure.figsize':(8,6)})
x = sns.histplot(x=MA["dosisFx"], hue=MA["Fx"], alpha = 0.75)
plt.title("Dosis por fracción",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Dosis [cGy]",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")

# %%
#4
sns.set(rc={'figure.figsize':(8,6)})
ax = sns.catplot(x=MA["dosisFx"], hue=MA["Fx"], kind="count", palette="deep", edgecolor="k",width=1)
plt.title("Dosis por fracción",size=18,fontname="DejaVu Sans",fontweight="bold")
plt.xlabel("Dosis [cGy]",size=14,fontname="DejaVu Sans")
plt.ylabel("#",size=14,fontname="DejaVu Sans")
plt.show()
#plt.savefig("isocentros_hist.pdf",bbox_inches="tight")
